# %%
import requests
import urllib.request
import time
from bs4 import BeautifulSoup

# %%
# Set the URL you want to webscrape from
url = 'http://www.nuforc.org/webreports/ndxevent.html'

# %%
# Connect to the URL
response = requests.get(url)

# %%
# Test response
response
# Out:
# <Response [200]>

# %%
# Parse HTML and save to BeautifulSoup object¶
soup = BeautifulSoup(response.text, "html.parser")

# %%
# Find links
soup.findAll('a')
# Out:
# [<a href="http://www.nwlink.com/~ufocntr">NUFORC Home</a>,
#  <a href="ndxe201905.html">05/2019</a>,
#  <a href="ndxe201904.html">04/2019</a>,
#  <a href="ndxe201903.html">03/2019</a>,
#  <a href="ndxe201902.html">02/2019</a>,
#  <a href="ndxe201901.html">01/2019</a>,
#  <a href="ndxe201812.html">12/2018</a>,
#  <a href="ndxe201811.html">11/2018</a>,
#  <a href="ndxe201810.html">10/2018</a>,
#  <a href="ndxe201809.html">09/2018</a>,
#  <a href="ndxe201808.html">08/2018</a>,
#  <a href="ndxe201807.html">07/2018</a>,
#  <a href="ndxe201806.html">06/2018</a>,
#  <a href="ndxe201805.html">05/2018</a>,
#  <a href="ndxe201804.html">04/2018</a>,
#  <a href="ndxe201803.html">03/2018</a>,
#  <a href="ndxe201802.html">02/2018</a>,
#  <a href="ndxe201801.html">01/2018</a>,
#  <a href="ndxe201712.html">12/2017</a>,
#  <a href="ndxe201711.html">11/2017</a>,
#  <a href="ndxe201710.html">10/2017</a>,
#  <a href="ndxe201709.html">09/2017</a>,
#  <a href="ndxe201708.html">08/2017</a>,
# ...

# %%
one_a_tag = soup.findAll('a')[1]
link = one_a_tag['href']

# %%
link
# Out:
# 'ndxe201905.html'

# %%
# To download the whole data set, let's do a for loop through all a tags
for i in range(1,115): #'a' tags are for links
    one_a_tag = soup.findAll('a')[i]
    link = one_a_tag['href']
    download_url = 'http://www.nuforc.org/webreports/'+ link
    urllib.request.urlretrieve(download_url,'./'+link[link.find('/ndxe_')+1:]) 
    time.sleep(2) #pause the code for a sec

# %%
# Combine text files into one
filenames = ['turnstile_190504.txt','turnstile_190511.txt']
with open('/Users/ashwingovindaraj/Desktop/Python Udemy/Combinedfile11', 'w') as outfile:
    for fname in filenames:
        with open(fname) as infile:
            outfile.write(infile.read())
